# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    ConfusionMatrixDisplay
)
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_validate
from imblearn.over_sampling import SMOTE
import numpy as np
from sklearn.impute import KNNImputer
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv('penguins_size.csv') # load the dataset

# %%
df.info() # check the data info before cleaning
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.isnull() # check for missing values
df.dropna(inplace=True) # drop rows with missing values

# %%
df.head() # view the first few rows
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 4  Adelie  Torgersen              36.7             19.3              193.0
# 5  Adelie  Torgersen              39.3             20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 4       3450.0  FEMALE
# 5       3650.0    MALE

# %%
df.info() # check again
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 334 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            334 non-null    object
#  1   island             334 non-null    object
#  2   culmen_length_mm   334 non-null    float64
#  3   culmen_depth_mm    334 non-null    float64
#  4   flipper_length_mm  334 non-null    float64
#  5   body_mass_g        334 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.9+ KB

# %%
plt.pie(df['species'].value_counts(), labels=df['species'].unique(), autopct='%1.1f%%') 
plt.title('Species Distribution') # pie chart of species distribution
plt.show() # display the pie chart

# %%
plt.pie(df['sex'].value_counts(), labels=df['sex'].unique(), autopct='%1.1f%%') 
plt.title('sex Distribution') # pie chart of species distribution
plt.show() # display the pie chart

# %%
df["sex"].unique()
# Out:
# array(['MALE', 'FEMALE', '.'], dtype=object)

# %%
df.drop(df[df["sex"] == "."].index, axis=0, inplace=True)

# %%
df["culmen_area"] = df["culmen_length_mm"] * df["culmen_depth_mm"]
df["flipper_area"] = df["body_mass_g"] * df["body_mass_g"] / 1000

# %%
plt.hist(df['culmen_length_mm'], bins=60, color='skyblue', edgecolor='black')
# Out:
# (array([ 1.,  0.,  1.,  1.,  1.,  4.,  5.,  6.,  9.,  7.,  6.,  6., 11.,
#          8.,  9.,  8., 13.,  6.,  9., 12.,  8.,  4.,  8.,  6., 11.,  3.,
#          3.,  3., 12., 15., 11., 13.,  9.,  8.,  4.,  8.,  8., 11.,  8.,
#         13., 12.,  9.,  4.,  7.,  2.,  1.,  2.,  0.,  2.,  0.,  1.,  2.,
#          0.,  0.,  0.,  0.,  1.,  0.,  0.,  1.]),
#  array([32.1       , 32.55833333, 33.01666667, 33.475     , 33.93333333,
#         34.39166667, 34.85      , 35.30833333, 35.76666667, 36.225     ,
#         36.68333333, 37.14166667, 37.6       , 38.05833333, 38.51666667,
#         38.975     , 39.43333333, 39.89166667, 40.35      , 40.80833333,
#         41.26666667, 41.725     , 42.18333333, 42.64166667, 43.1       ,
#         43.55833333, 44.01666667, 44.475     , 44.93333333, 45.39166667,
#         45.85      , 46.30833333, 46.76666667, 47.225     , 47.68333333,
#         48.14166667, 48.6       , 49.05833333, 49.51666667, 49.975     ,
#         50.43333333, 50.89166667, 51.35      , 51.80833333, 52.26666667,
#         52.725     , 53.18333333, 53.64166667, 54.1       , 54.55833333,
#         55.01666667, 55.475     , 55.93333333, 56.39166667, 56.85      ,
#         57.30833333, 57.76666667, 58.225     , 58.68333333, 59.14166667,
#         59.6       ]),
#  <BarContainer object of 60 artists>)

# %%
plt.hist(df['culmen_depth_mm'], bins=60, color='skyblue', edgecolor='black') # plot histogram of 'culmen_depth_mm' after removing outliers
# Out:
# (array([ 2.,  1.,  3.,  1.,  6.,  7.,  2.,  9.,  3.,  4., 13.,  2.,  4.,
#         10.,  3.,  8.,  2.,  5.,  5.,  4.,  9.,  6.,  7.,  2.,  4.,  8.,
#          4., 14.,  7.,  6.,  9.,  6.,  6.,  9., 10., 13.,  5.,  9., 10.,
#         10., 13.,  8., 14.,  4.,  2., 11.,  3.,  5.,  3.,  6.,  1.,  3.,
#          1.,  1.,  3.,  1.,  0.,  5.,  0.,  1.]),
#  array([13.1 , 13.24, 13.38, 13.52, 13.66, 13.8 , 13.94, 14.08, 14.22,
#         14.36, 14.5 , 14.64, 14.78, 14.92, 15.06, 15.2 , 15.34, 15.48,
#         15.62, 15.76, 15.9 , 16.04, 16.18, 16.32, 16.46, 16.6 , 16.74,
#         16.88, 17.02, 17.16, 17.3 , 17.44, 17.58, 17.72, 17.86, 18.  ,
#         18.14, 18.28, 18.42, 18.56, 18.7 , 18.84, 18.98, 19.12, 19.26,
#         19.4 , 19.54, 19.68, 19.82, 19.96, 20.1 , 20.24, 20.38, 20.52,
#         20.66, 20.8 , 20.94, 21.08, 21.22, 21.36, 21.5 ]),
#  <BarContainer object of 60 artists>)

# %%
plt.hist(df['body_mass_g'], bins=60, color='skyblue', edgecolor='black') # plot histogram of 'body_mass_g' after removing outliers
# Out:
# (array([ 1.,  0.,  2.,  5.,  0.,  6.,  2.,  6.,  5.,  6., 15.,  8., 12.,
#          9., 10., 14., 12., 12., 13.,  2., 20.,  6.,  7.,  4.,  6.,  9.,
#          9.,  3.,  8.,  6.,  5.,  6.,  7.,  8.,  6.,  7.,  4.,  5.,  6.,
#          3.,  5.,  4.,  3.,  4.,  3.,  6.,  5.,  6.,  2.,  3.,  6.,  2.,
#          3.,  0.,  2.,  3.,  0.,  0.,  0.,  1.]),
#  array([2700., 2760., 2820., 2880., 2940., 3000., 3060., 3120., 3180.,
#         3240., 3300., 3360., 3420., 3480., 3540., 3600., 3660., 3720.,
#         3780., 3840., 3900., 3960., 4020., 4080., 4140., 4200., 4260.,
#         4320., 4380., 4440., 4500., 4560., 4620., 4680., 4740., 4800.,
#         4860., 4920., 4980., 5040., 5100., 5160., 5220., 5280., 5340.,
#         5400., 5460., 5520., 5580., 5640., 5700., 5760., 5820., 5880.,
#         5940., 6000., 6060., 6120., 6180., 6240., 6300.]),
#  <BarContainer object of 60 artists>)

# %%
plt.hist(df['body_mass_g'], bins=60, color='skyblue', edgecolor='black') # plot histogram of 'body_mass_g' after removing outliers
# Out:
# (array([ 1.,  0.,  2.,  5.,  0.,  6.,  2.,  6.,  5.,  6., 15.,  8., 12.,
#          9., 10., 14., 12., 12., 13.,  2., 20.,  6.,  7.,  4.,  6.,  9.,
#          9.,  3.,  8.,  6.,  5.,  6.,  7.,  8.,  6.,  7.,  4.,  5.,  6.,
#          3.,  5.,  4.,  3.,  4.,  3.,  6.,  5.,  6.,  2.,  3.,  6.,  2.,
#          3.,  0.,  2.,  3.,  0.,  0.,  0.,  1.]),
#  array([2700., 2760., 2820., 2880., 2940., 3000., 3060., 3120., 3180.,
#         3240., 3300., 3360., 3420., 3480., 3540., 3600., 3660., 3720.,
#         3780., 3840., 3900., 3960., 4020., 4080., 4140., 4200., 4260.,
#         4320., 4380., 4440., 4500., 4560., 4620., 4680., 4740., 4800.,
#         4860., 4920., 4980., 5040., 5100., 5160., 5220., 5280., 5340.,
#         5400., 5460., 5520., 5580., 5640., 5700., 5760., 5820., 5880.,
#         5940., 6000., 6060., 6120., 6180., 6240., 6300.]),
#  <BarContainer object of 60 artists>)

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
sns.pairplot(df, hue="species")   
plt.show()

# %%
models = []
models.append(('LR', LogisticRegression()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('DECT', DecisionTreeClassifier()))
models.append(('RC', RandomForestClassifier()))
models.append(('GUSS', GaussianNB()))  
models.append(('XG', XGBClassifier(use_label_encoder=False, eval_metric='logloss')))  
models.append(('SVM', SVC()))

# %%
df.columns = df.columns.str.strip()

# %%
x= df.drop(columns=['species'])
y= df['species']
y = LabelEncoder().fit_transform(y)
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42, stratify=y
)



preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='error', sparse_output=False), ['island', 'sex']),
        ('num', MinMaxScaler(), ['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm', 'body_mass_g', 'culmen_area', 'flipper_area'])
    ]
)
for model in models:
        
    # Pipeline: Preprocessor + Model
    pipeline = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('classifier', model[1])
    ])
    
    pipeline.fit(X_train, y_train)
    scores = cross_validate(pipeline, X_train, y_train, cv=5, scoring=['accuracy', 'precision_weighted', 'recall_weighted', 'f1_weighted'], return_train_score=True)

    # Print results
    print(f"Model: {model[1]}")
    print("Train Accuracy : ", scores["train_accuracy"].mean())
    print("Test Accuracy  : ", scores["test_accuracy"].mean())
    print("Train Precision: ", scores["train_precision_weighted"].mean())
    print("Test Precision : ", scores["test_precision_weighted"].mean())
    print("Train Recall   : ", scores["train_recall_weighted"].mean())
    print("Test Recall    : ", scores["test_recall_weighted"].mean())
    print("Train F1 Score : ", scores["train_f1_weighted"].mean())
    print("Test F1 Score  : ", scores["test_f1_weighted"].mean())
    print('-'*60)
# Out:
# Model: LogisticRegression()
# Train Accuracy :  0.9943617680928337
# Test Accuracy  :  0.9924528301886791
# Train Precision:  0.9944786926142012
# Test Precision :  0.9927610062893082
# Train Recall   :  0.9943617680928337
# Test Recall    :  0.9924528301886791
# Train F1 Score :  0.9943238769665561
# Test F1 Score  :  0.9923423285517803
# ------------------------------------------------------------
# Model: KNeighborsClassifier()
# Train Accuracy :  0.9981220657276996
# Test Accuracy  :  0.992522711390636
# Train Precision:  0.9981418334568817
# Test Precision :  0.9929822967621709
# Train Recall   :  0.9981220657276996
# Test Recall    :  0.992522711390636
# Train F1 Score :  0.9981159871355949
# Test F1 Score  :  0.9925030266877982
# ------------------------------------------------------------
# Model: DecisionTreeClassifier()
# Train Accuracy :  1.0
# Test Accuracy  :  0.9660377358490567
# Train Precision:  1.0
# Test Precision :  0.9669982847341337
# Train Recall   :  1.0
# Test Recall    :  0.9660377358490567
# Train F1 Score :  1.0
# Test F1 Score  :  0.9661169402104595
# ------------------------------------------------------------
# Model: RandomForestClassifier()
# Train Accuracy :  1.0
# Test Accuracy  :  0.9924528301886791
# Train Precision:  1.0
# Test Precision :  0.993033381712627
# Train Recall   :  1.0
# Test Recall    :  0.9924528301886791
# Train F1 Score :  1.0
# Test F1 Score  :  0.9921844863731657
# ------------------------------------------------------------
# Model: GaussianNB()
# Train Accuracy :  0.7283816104172203
# Test Accuracy  :  0.7253668763102724
# Train Precision:  0.8282222325577511
# Test Precision :  0.829396671183849
# Train Recall   :  0.7283816104172203
# Test Recall    :  0.7253668763102724
# Train F1 Score :  0.6989853761601131
# Test F1 Score  :  0.694077329381307
# ------------------------------------------------------------
# c:\Users\mosta\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\training.py:183: UserWarning: [00:06:21] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\mosta\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\training.py:183: UserWarning: [00:06:21] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\mosta\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\training.py:183: UserWarning: [00:06:21] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\mosta\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\training.py:183: UserWarning: [00:06:21] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\mosta\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\training.py:183: UserWarning: [00:06:21] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\mosta\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\training.py:183: UserWarning: [00:06:21] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Model: XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, ...)
# Train Accuracy :  1.0
# Test Accuracy  :  0.9886792452830189
# Train Precision:  1.0
# Test Precision :  0.9888364779874215
# Train Recall   :  1.0
# Test Recall    :  0.9886792452830189
# Train F1 Score :  1.0
# Test F1 Score  :  0.9886295425436333
# ------------------------------------------------------------
# Model: SVC()
# Train Accuracy :  0.9962397023651341
# Test Accuracy  :  0.9962264150943396
# Train Precision:  0.9962793900889757
# Test Precision :  0.996377358490566
# Train Recall   :  0.9962397023651341
# Test Recall    :  0.9962264150943396
# Train F1 Score :  0.9962275575372134
# Test F1 Score  :  0.9961656161968262
# ------------------------------------------------------------
